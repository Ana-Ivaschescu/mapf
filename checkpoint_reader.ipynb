# %%
path_to_file = r"\\aalbes\D\mapformer\runs\conditional_scd\hrscd\mapformer_f_swin_c3po_basic\best_SCS_iter_42000.pth"

# %%
import torch

tensor = torch.load(path_to_file, map_location="cpu")

# %%
type(tensor)
# Out:
# dict

# %%
import shutil
from typing import Any
 
 
def stringify(
    obj: Any,
    indent_level: int = 0,
    max_line_len: int = 0,
    ignore = None,
) -> str:
    """Stringify an object with indentation and line breaks.
 
    Args:
        obj: The object to stringify.
        indent_level: The current indentation level. The indentation itself
            is displayed as 4 spaces per level. In most cases, you can leave
            this at 0. It is used internally for recursive calls.
        max_line_len: The maximum line length before breaking. If set to 0,
            the terminal width will be used.
        ignore: A list of types to ignore. If the object is of one of these
            types, it will be stringified as "type(obj)".
 
    Returns:
        The stringified object.
    """
    if max_line_len == 0:
        max_line_len = shutil.get_terminal_size().columns
 
    indent = " " * 4 * indent_level
    indent_next = " " * 4 * (indent_level + 1)
 
    if ignore is not None and isinstance(obj, ignore):
        return type(obj).__name__
 
    repr_obj = repr(obj)
 
    if len(repr_obj) <= max_line_len:
        return repr_obj
 
    if isinstance(obj, list):
        return (
            "[\n"
            + ",\n".join(
                indent_next
                + stringify(
                    item,
                    indent_level=indent_level + 1,
                    max_line_len=max_line_len,
                    ignore=ignore,
                )
                for item in obj
            )
            + "\n"
            + indent
            + "]"
        )
 
    if isinstance(obj, tuple):
        return (
            "(\n"
            + ",\n".join(
                indent_next
                + stringify(
                    item,
                    indent_level=indent_level + 1,
                    max_line_len=max_line_len,
                    ignore=ignore,
                )
                for item in obj
            )
            + "\n"
            + indent
            + ")"
        )
 
    if isinstance(obj, dict):
        return (
            "{\n"
            + ",\n".join(
                indent_next
                + repr(key)
                + ": "
                + stringify(
                    value,
                    indent_level=indent_level + 1,
                    max_line_len=max_line_len,
                    ignore=ignore,
                )
                for key, value in obj.items()
            )
            + "\n"
            + indent
            + "}"
        )
 
    return repr_obj

# %%
print(stringify(tensor, max_line_len=80, ignore=torch.Tensor))
# Out:
# {
#     'meta': {
#         'env_info': 'sys.platform: win32\nPython: 3.9.18 (main, Sep 11 2023, 14:09:26) [MSC v.1916 64 bit (AMD64)]\nCUDA available: True\nGPU 0: NVIDIA RTX A5000\nCUDA_HOME: C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.2\nNVCC: Cuda compilation tools, release 11.2, V11.2.67\nMSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.39.33523 for x64\nGCC: n/a\nPyTorch: 1.8.0+cu111\nPyTorch compiling details: PyTorch built with:\n  - C++ Version: 199711\n  - MSVC 192829337\n  - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications\n  - Intel(R) MKL-DNN v1.7.0 (Git Hash 7aed236906b1f7a05c0917e5257a1af05e9ff683)\n  - OpenMP 2019\n  - CPU capability usage: AVX2\n  - CUDA Runtime 11.1\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37\n  - CuDNN 8.0.5\n  - Magma 2.5.4\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=C:/w/b/windows/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /w /bigobj -DUSE_PTHREADPOOL -openmp:experimental -DNDEBUG -DUSE_FBGEMM -DUSE_XNNPACK, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.8.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, \n\nTorchVision: 0.9.0+cu111\nOpenCV: 4.8.1\nMMCV: 1.5.0\nMMCV Compiler: MSVC 192930137\nMMCV CUDA Compiler: 11.1\nMMSegmentation: 0.11.0+64009f0',
#         'seed': None,
#         'exp_name': 'mapformer_f_swin.yaml',
#         'hook_msgs': {
#             'best_score': 0.27606576077961814,
#             'best_ckpt': '\\\\aalbes\\D\\mapformer\\runs\\conditional_scd\\hrscd\\mapformer_f_swin_c3po_basic\\best_SCS_iter_42000.pth'
#         },
#         'epoch': 5,
#         'iter': 41999,
#         'mmcv_version': '1.5.0',
#         'time': 'Thu May 23 22:50:23 2024',
#         'CLASSES': ['artificial', 'agricultural', 'forest', 'wetland', 'water']
#     },
#     'state_dict': {
#         'decode_head.conv_seg_bc.weight': Tensor,
#         'decode_head.conv_seg_bc.bias': Tensor,
#         'decode_head.conv_seg_sem.weight': Tensor,
#         'decode_head.conv_seg_sem.bias': Tensor,
#         'decode_head.map_encoder.layer1.weight': Tensor,
#         'decode_head.map_encoder.layer1.bias': Tensor,
#         'decode_head.map_encoder.layer2.conv.weight': Tensor,
#         'decode_head.map_encoder.layer2.bn.weight': Tensor,
#         'decode_head.map_encoder.layer2.bn.bias': Tensor,
#         'decode_head.map_encoder.layer2.bn.running_mean': Tensor,
#         'decode_head.map_encoder.layer2.bn.running_var': Tensor,
#         'decode_head.map_encoder.layer2.bn.num_batches_tracked': Tensor,
#         'decode_head.map_encoder.layer3.conv.weight': Tensor,
#         'decode_head.map_encoder.layer3.bn.weight': Tensor,
#         'decode_head.map_encoder.layer3.bn.bias': Tensor,
#         'decode_head.map_encoder.layer3.bn.running_mean': Tensor,
#         'decode_head.map_encoder.layer3.bn.running_var': Tensor,
#         'decode_head.map_encoder.layer3.bn.num_batches_tracked': Tensor,
#         'decode_head.temporal_fusion_modules.0.i1.weight': Tensor,
#         'decode_head.temporal_fusion_modules.0.i2.weight': Tensor,
#         'decode_head.temporal_fusion_modules.0.app.weight': Tensor,
#         'decode_head.temporal_fusion_modules.0.exchange.weight': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv1.conv.weight': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv1.bn.weight': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv1.bn.bias': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv1.bn.running_mean': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv1.bn.running_var': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv1.bn.num_batches_tracked': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv2.conv.weight': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv2.bn.weight': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv2.bn.bias': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv2.bn.running_mean': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv2.bn.running_var': Tensor,
#         'decode_head.temporal_fusion_modules.0.conv2.bn.num_batches_tracked': Tensor,
#         'decode_head.temporal_fusion_modules.1.i1.weight': Tensor,
#         'decode_head.temporal_fusion_modules.1.i2.weight': Tensor,
#         'decode_head.temporal_fusion_modules.1.app.weight': Tensor,
#         'decode_head.temporal_fusion_modules.1.exchange.weight': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv1.conv.weight': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv1.bn.weight': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv1.bn.bias': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv1.bn.running_mean': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv1.bn.running_var': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv1.bn.num_batches_tracked': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv2.conv.weight': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv2.bn.weight': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv2.bn.bias': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv2.bn.running_mean': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv2.bn.running_var': Tensor,
#         'decode_head.temporal_fusion_modules.1.conv2.bn.num_batches_tracked': Tensor,
#         'decode_head.temporal_fusion_modules.2.i1.weight': Tensor,
#         'decode_head.temporal_fusion_modules.2.i2.weight': Tensor,
#         'decode_head.temporal_fusion_modules.2.app.weight': Tensor,
#         'decode_head.temporal_fusion_modules.2.exchange.weight': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv1.conv.weight': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv1.bn.weight': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv1.bn.bias': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv1.bn.running_mean': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv1.bn.running_var': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv1.bn.num_batches_tracked': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv2.conv.weight': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv2.bn.weight': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv2.bn.bias': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv2.bn.running_mean': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv2.bn.running_var': Tensor,
#         'decode_head.temporal_fusion_modules.2.conv2.bn.num_batches_tracked': Tensor,
#         'decode_head.temporal_fusion_modules.3.i1.weight': Tensor,
#         'decode_head.temporal_fusion_modules.3.i2.weight': Tensor,
#         'decode_head.temporal_fusion_modules.3.app.weight': Tensor,
#         'decode_head.temporal_fusion_modules.3.exchange.weight': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv1.conv.weight': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv1.bn.weight': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv1.bn.bias': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv1.bn.running_mean': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv1.bn.running_var': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv1.bn.num_batches_tracked': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv2.conv.weight': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv2.bn.weight': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv2.bn.bias': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv2.bn.running_mean': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv2.bn.running_var': Tensor,
#         'decode_head.temporal_fusion_modules.3.conv2.bn.num_batches_tracked': Tensor,
#         'decode_head.attention_weights.0.weight': Tensor,
#         'decode_head.attention_weights.0.bias': Tensor,
#         'decode_head.attention_weights.1.weight': Tensor,
#         'decode_head.attention_weights.1.bias': Tensor,
#         'decode_head.attention_weights.2.weight': Tensor,
#         'decode_head.attention_weights.2.bias': Tensor,
#         'decode_head.attention_weights.3.weight': Tensor,
#         'decode_head.attention_weights.3.bias': Tensor,
#         'decode_head.fusion_conv.conv.weight': Tensor,
#         'decode_head.fusion_conv.bn.weight': Tensor,
#         'decode_head.fusion_conv.bn.bias': Tensor,
#         'decode_head.fusion_conv.bn.running_mean': Tensor,
#         'decode_head.fusion_conv.bn.running_var': Tensor,
#         'decode_head.fusion_conv.bn.num_batches_tracked': Tensor,
#         'decode_head.contrastive_img_forward.conv_seg.weight': Tensor,
#         'decode_head.contrastive_img_forward.conv_seg.bias': Tensor,
#         'decode_head.contrastive_img_forward.convs.0.conv.weight': Tensor,
#         'decode_head.contrastive_img_forward.convs.0.bn.weight': Tensor,
#         'decode_head.contrastive_img_forward.convs.0.bn.bias': Tensor,
#         'decode_head.contrastive_img_forward.convs.0.bn.running_mean': Tensor,
#         'decode_head.contrastive_img_forward.convs.0.bn.running_var': Tensor,
#         'decode_head.contrastive_img_forward.convs.0.bn.num_batches_tracked': Tensor,
#         'decode_head.contrastive_img_forward.convs.1.conv.weight': Tensor,
#         'decode_head.contrastive_img_forward.convs.1.bn.weight': Tensor,
#         'decode_head.contrastive_img_forward.convs.1.bn.bias': Tensor,
#         'decode_head.contrastive_img_forward.convs.1.bn.running_mean': Tensor,
#         'decode_head.contrastive_img_forward.convs.1.bn.running_var': Tensor,
#         'decode_head.contrastive_img_forward.convs.1.bn.num_batches_tracked': Tensor,
#         'decode_head.contrastive_img_forward.convs.2.conv.weight': Tensor,
#         'decode_head.contrastive_img_forward.convs.2.bn.weight': Tensor,
#         'decode_head.contrastive_img_forward.convs.2.bn.bias': Tensor,
#         'decode_head.contrastive_img_forward.convs.2.bn.running_mean': Tensor,
#         'decode_head.contrastive_img_forward.convs.2.bn.running_var': Tensor,
#         'decode_head.contrastive_img_forward.convs.2.bn.num_batches_tracked': Tensor,
#         'decode_head.contrastive_img_forward.convs.3.conv.weight': Tensor,
#         'decode_head.contrastive_img_forward.convs.3.bn.weight': Tensor,
#         'decode_head.contrastive_img_forward.convs.3.bn.bias': Tensor,
#         'decode_head.contrastive_img_forward.convs.3.bn.running_mean': Tensor,
#         'decode_head.contrastive_img_forward.convs.3.bn.running_var': Tensor,
#         'decode_head.contrastive_img_forward.convs.3.bn.num_batches_tracked': Tensor,
#         'decode_head.contrastive_img_forward.fusion_conv.conv.weight': Tensor,
#         'decode_head.contrastive_img_forward.fusion_conv.bn.weight': Tensor,
#         'decode_head.contrastive_img_forward.fusion_conv.bn.bias': Tensor,
#         'decode_head.contrastive_img_forward.fusion_conv.bn.running_mean': Tensor,
#         'decode_head.contrastive_img_forward.fusion_conv.bn.running_var': Tensor,
#         'decode_head.contrastive_img_forward.fusion_conv.bn.num_batches_tracked': Tensor,
#         'backbone.embeddings.patch_embeddings.projection.weight': Tensor,
#         'backbone.embeddings.patch_embeddings.projection.bias': Tensor,
#         'backbone.embeddings.norm.weight': Tensor,
#         'backbone.embeddings.norm.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.0.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.0.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.0.output.dense.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.output.dense.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.0.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.0.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.1.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.1.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.1.output.dense.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.output.dense.bias': Tensor,
#         'backbone.encoder.layers.0.blocks.1.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.0.blocks.1.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.0.downsample.reduction.weight': Tensor,
#         'backbone.encoder.layers.0.downsample.norm.weight': Tensor,
#         'backbone.encoder.layers.0.downsample.norm.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.0.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.0.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.0.output.dense.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.output.dense.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.0.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.0.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.1.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.1.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.1.output.dense.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.output.dense.bias': Tensor,
#         'backbone.encoder.layers.1.blocks.1.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.1.blocks.1.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.1.downsample.reduction.weight': Tensor,
#         'backbone.encoder.layers.1.downsample.norm.weight': Tensor,
#         'backbone.encoder.layers.1.downsample.norm.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.0.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.0.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.0.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.0.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.0.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.1.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.1.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.1.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.1.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.1.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.2.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.2.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.2.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.2.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.2.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.3.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.3.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.3.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.3.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.3.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.4.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.4.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.4.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.4.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.4.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.5.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.5.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.5.output.dense.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.output.dense.bias': Tensor,
#         'backbone.encoder.layers.2.blocks.5.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.2.blocks.5.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.2.downsample.reduction.weight': Tensor,
#         'backbone.encoder.layers.2.downsample.norm.weight': Tensor,
#         'backbone.encoder.layers.2.downsample.norm.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.0.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.0.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.0.output.dense.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.output.dense.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.0.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.0.layernorm_after.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.logit_scale': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.relative_coords_table': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.relative_position_index': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.continuous_position_bias_mlp.0.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.continuous_position_bias_mlp.0.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.continuous_position_bias_mlp.2.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.query.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.query.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.key.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.value.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.self.value.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.output.dense.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.attention.output.dense.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.1.layernorm_before.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.layernorm_before.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.1.intermediate.dense.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.intermediate.dense.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.1.output.dense.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.output.dense.bias': Tensor,
#         'backbone.encoder.layers.3.blocks.1.layernorm_after.weight': Tensor,
#         'backbone.encoder.layers.3.blocks.1.layernorm_after.bias': Tensor,
#         'backbone.layernorm.weight': Tensor,
#         'backbone.layernorm.bias': Tensor
#     },
#     'optimizer': {
#         'state': {
#             0: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             1: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             2: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             3: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             4: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             5: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             6: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             7: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             8: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             9: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             10: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             11: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             12: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             13: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             14: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             15: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             16: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             17: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             18: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             19: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             20: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             21: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             22: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             23: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             24: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             25: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             26: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             27: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             28: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             29: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             30: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             31: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             32: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             33: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             34: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             35: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             36: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             37: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             38: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             39: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             40: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             41: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             42: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             43: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             44: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             45: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             46: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             47: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             48: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             49: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             50: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             51: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             52: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             53: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             54: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             55: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             56: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             57: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             58: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             59: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             60: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             61: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             62: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             63: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             64: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             65: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             66: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             67: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             68: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             69: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             70: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             71: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             72: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             73: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             74: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             75: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             76: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             77: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             78: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             79: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             80: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             81: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             82: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             83: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             84: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             85: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             86: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             87: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             88: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             89: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             90: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             91: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             92: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             93: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             94: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             95: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             96: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             97: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             98: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             99: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             100: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             101: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             102: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             103: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             104: {
#                 'step': 42000,
#                 'exp_avg': Tensor,
#                 'exp_avg_sq': Tensor
#             },
#             105: {
#                 'step': 42000,
# ...
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [267]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [268]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [269]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [270]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [271]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [272]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [273]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [274]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [275]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [276]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [277]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [278]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [279]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [280]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [281]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [282]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [283]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [284]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [285]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [286]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [287]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [288]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [289]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [290]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [291]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [292]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [293]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [294]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [295]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [296]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [297]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [298]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [299]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [300]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [301]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [302]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [303]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [304]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [305]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [306]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [307]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [308]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [309]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [310]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [311]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [312]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [313]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [314]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [315]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [316]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'weight_decay': 0.01,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [317]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.01,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [318]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [319]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [320]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [321]
#             },
#             {
#                 'lr': 2.0625937499999998e-05,
#                 'weight_decay': 0.0,
#                 'betas': [0.9, 0.999],
#                 'eps': 1e-08,
#                 'amsgrad': False,
#                 'initial_lr': 6e-05,
#                 'params': [322]
#             }
#         ]
#     }
# }
